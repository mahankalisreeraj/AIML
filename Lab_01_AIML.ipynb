# %% [markdown]
# <a href="https://colab.research.google.com/github/mahankalisreeraj/AIML/blob/main/Lab_01_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Lab-01 : Activity-1:Implement Basic Data Structures Using Numpy,Pandas

# %%
import numpy as np
list1=[1,2,3]
array1=np.array(list1)
type(array1)

# %% [markdown]
# **Mathematical Operations using numpy

# %%
list2=[3,2,1]
array2=np.array(list2)

# %%
print(f'Addition of two arrays:,{array1 + array2}')
print(f'Multiplication of two arrays:,{array1 * array2}')
print(f'power of two arrays:,{array1 ** array2}')

# %% [markdown]
# **Mathematical Functions in Numpy

# %%
print(f'sin value of array1:,{np.sin(array1)}')
print(f'Log2 value of array1:,{np.log2(array1)}')
print(f'Exponential value of array1:,{np.exp(array1)}')

# %% [markdown]
# EX-1 Scatterplot

# %%
people=['Ann','Brandon','Chen','David']
age=[21,12,32,45]
weight=[55,37,77,68]
height=[160,135,170,165]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(age,weight,height)
plt.title("Weight vs Height:",fontsize=16)
plt.show()

# %% [markdown]
# Bar Chart

# %%
plt.figure(figsize=(4,4))
plt.title("People's weight in kgs",fontsize=16)
plt.bar(x=people,height=weight,width=0.6,color="orange",edgecolor="b",alpha=0.6)
plt.xlabel("people",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("weigt(in kgs)", fontsize=16)
plt.show()

# %% [markdown]
# Histogram

# %%
plt.figure(figsize=(4,4))

plt.hist(weight,color="yellow",edgecolor="k",alpha=0.6,bins=9)
plt.title("Histogram of people's Weight:",fontsize=16)
plt.xlabel("Weight(in Kgs)")
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ##How to read data from different data sources

# %%
import numpy as np
import pandas as pd
import nbconvert

# %%
df1=pd.read_table("Book2.txt")
df1
# Out:
#     people  Age  Weight  Height
# 0      Ann   21      55     160
# 1  Brandon   12      37     135
# 2     Chen   32      77     170
# 3    David   45      68     165

# %%
df2=pd.read_csv("Book(1).csv")
df2
# Out:
#     people  Age  Weight  Height
# 0      Ann   21      55     160
# 1  Brandon   12      37     135
# 2     Chen   32      77     170
# 3    David   45      68     165

# %%
df3=pd.read_excel("Book1.xlsx")
df3
# Out:
#     people  Age  Weight  Height
# 0      Ann   21      55     160
# 1  Brandon   12      37     135
# 2     Chen   32      77     170
# 3    David   45      68     165
